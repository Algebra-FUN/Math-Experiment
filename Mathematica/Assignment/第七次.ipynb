# %% [markdown]
# ![image.png](attachment:e21dd2f1-0ba8-4189-896f-62dfad0480ea.png)

# %%
num = RandomReal[];
If[num<0.5,num,"This number is greater than or equal to 0.5"]
# Out:
# 0.0173167

# %% [markdown]
# ![image.png](attachment:a21f92bc-3596-4234-8c2a-a1f8f55cc4f5.png)

# %%
DerivateZeroCheck[y_]:=If[D[y,x]==0,"y'(x)=0","y'(x)!=0"];

# %%
DerivateZeroCheck[x]
# Out:
# y'(x)!=0

# %%
DerivateZeroCheck[1]
# Out:
# y'(x)=0

# %% [markdown]
# ![image.png](attachment:15f8f8fa-e1c4-48c4-a696-72d106877644.png)

# %%
INorm[x_]:={x//Abs//Total,x//#^2&//Total//Sqrt,x//Abs//Max}

# %%
{1,2,-3,4,z}//INorm
# Out:
#                          2
# {10 + Abs[z], Sqrt[30 + z ], Max[4, Abs[z]]}

# %% [markdown]
# ![image.png](attachment:5f71cc0a-864e-4d94-adae-83685dc1f426.png)

# %%
Mod3[x_]:=Mod[x,3];
Range[10]//Mod3
# Out:
# {1, 2, 0, 1, 2, 0, 1, 2, 0, 1}

# %% [markdown]
# ![image.png](attachment:e6bfccf9-5ea9-401b-ac41-c76962107460.png)

# %%
IFactors[n_]:=Select[Range[n],Mod[n,#]==0&];
IFactors[12]
# Out:
# {1, 2, 3, 4, 6, 12}

# %% [markdown]
# ![image.png](attachment:004d1af6-a93e-41cb-8cce-243760e489d9.png)

# %%
HalfDays[l_]:= Log[l]/Log[2]+1//N//Floor;
HalfDays[32768]
# Out:
# 16

# %% [markdown]
# ## 7.
# 将等差数列{an}: an =4n-1 (n为正整数)中所有能被3或5整除的数删去后，剩下的数自小到大排成一个数列{bk}。请构造一个函数，可以针对输入的m,首先检查其是否为正整数，如果是，则打印出{ bk}（k=1,…,m），并且请计算b2005

# %%
b = Select[Table[4n-1,{n,10^4}],Mod[#,3]*Mod[#,5]!=0&];
b[[2005]]
# Out:
# 15031

# %% [markdown]
# ## 8.
# 将正奇数集合{1,3,5,…}从小到达按第n组有2n-1个奇数进行分组：{1},{3,5,7},{9,11,13,15,17},…. 请编写函数给定任意正奇数k，输出其位于第几组。并求出1991,3021位于第几组？

# %%
OddLoc[k_]:=(k+1)/2//Sqrt//Ceiling

# %%
OddLoc[1991]
# Out:
# 32

# %%
OddLoc[3021]
# Out:
# 39
